# %% [markdown]
# <a href="https://colab.research.google.com/github/Adrwv/PythonUdemy/blob/main/Cadenas_de_texto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Funciones con cadenas**

# %%
cadena = 'Hola mundo'

# %%
#Se muestra la longitud de la cadena

# %%
len(cadena)
# Out:
# 10

# %%
#se convierte a mayusculas

# %%
cadena.upper()
# Out:
# 'HOLA MUNDO'

# %%
#se convierte a minusculas

# %%
cadena.lower()
# Out:
# 'hola mundo'

# %%
#Con tabulador muestra opciones de funciones

# %% [markdown]
# ![image.png](attachment:1018ee3e-7ee6-4026-b7ae-eeab3591f09d.png)

# %%
#impirmir variables en una cadena

# %%
nombre =  'Antonio'
print('Buenos días', nombre)
# Out:
# Buenos días Antonio

# %%
#.format

# %%
nombre =  'Andrés'
edad = 36
print('Buenos días {} feliz cumpleaños numero {}'.format(nombre, edad))
# Out:
# Buenos días Andrés feliz cumpleaños numero 36

# %%
resultado = 10 / 3

# %%
resultado
# Out:
# 3.3333333333333335

# %%
print('El resultado de {r}'.format(r=resultado))
# Out:
# El resultado de 3.3333333333333335

# %%
#Le da formato a los decimales

# %%
print('El resultado de {r:1.2f}'.format(r=resultado))
# Out:
# El resultado de 3.33

# %%
#f strings

# %%
nombre = 'Antonio'
edad = 36

# %%
print(f"Buenos días {nombre}, feliz cumpleaños {edad}" )
# Out:
# Buenos días Antonio, feliz cumpleaños 36

# %%
#entrada por teclado

# %%
print('Cual es tu nombre')
entrada =  input()
print('Hola ' + entrada)
# Out:
# Cual es tu nombre
#  Andrés
# Hola Andrés

# %%
#ejercico de slicing

# %% [markdown]
# ![imagen_2022-11-29_124433592.png](data:image/png;base64,...)

# %%
cadena =  'Esto es un texto de ejemplo'
len(cadena)
# Out:
# 27

# %%
cadena[11:16]
# Out:
# 'texto'

# %% [markdown]
# ![imagen_2022-11-29_124353064.png](data:image/png;base64,...)

# %%
cadena =  'Esto es un texto de ejemplo'
print(cadena)
longitud =  len(cadena)
print(longitud)
strlongitud =  str(longitud)
print(strlongitud)
mayusculas = cadena.upper()
resultado = mayusculas + ' tiene la longitud de ' + strlongitud
print(resultado)
# Out:
# Esto es un texto de ejemplo
# 27
# 27
# ESTO ES UN TEXTO DE EJEMPLO tiene la longitud de 27

# %% [markdown]
# ![imagen_2022-11-29_124308916.png](data:image/png;base64,...)

# %%
numero1 = 5
numero2 = 8
suma = numero1 + numero2
print(suma)
# Out:
# 13

# %% [markdown]
# ![imagen_2022-11-29_124201038.png](data:image/png;base64,...)

# %%
print('Introdce el primer nuemero')
dato1 =  input()
print('Introdce el segundo nuemero')
dato2 =  input()
numero1 = float(dato1)
numero2 = float(dato2)
suma = numero1 + numero2
strSuma = str(suma)
resultado = 'La suma es ' + strSuma
print(resultado)
# Out:
# Introdce el primer nuemero
#  1
# Introdce el segundo nuemero
#  2
# La suma es 3.0
